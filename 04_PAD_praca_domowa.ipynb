# %% [markdown]
# <a href="https://colab.research.google.com/github/aniabor/Homework-PAD13c/blob/main/04_PAD_praca_domowa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Zadanie 1 (5 pkt)
#
#
# Wgraj zawartość pliku orders.csv do ramki danych.
# Przyjrzyj się danym, wykorzystując poznane metody (describe, info, head) zanalizuj dane.
#
# Następnie:
#
#
#
# 1. Zamień order_date na format daty. Upewnij się, że w rezultacie data będzie w formacie: rok-miesiąc-dzień;
# 2. Sprawdź ile i jakie unikalne wartości znajdują się w kolumnie T-shirt category;
# 3. Wyczyść kolumnę tshirt_category normalizując nazwy produktów. Upewnij się, że dla każdej kategorii funkcjonuje jedna nazwa, np. zamiast white i wh jest tylko jedna wersja white. Skorzystaj z klasy string i metody apply;
# 4. Rozdziel kolumnę tshirt category na 3 kolumny: tshirt_type, która będzie mówiła o tym czy jest to koszulka, bluza czy coś innego, tshirt_size, która będzie informowała o rozmiarze koszulki, i tshirt_colour, która będzie informowała o kolorze. Skorzystaj z metody apply.
# 5. Znajdź zamówienia złożone między 31 grudnia 2014 a 2 sierpnia 2016.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('/content/drive/MyDrive/PJATK/PAD/ćwiczenia/PAD_04/orders.csv')
data
df = pd.DataFrame(data)
df
# Out:
#        order_date  pages_visited         order_id customer_id  \
# 0      2016/09/04              9  HTS-038040-0002      038040
# 1      2014/11/14             11  HTS-801797-0001      801797
# 2      2017/02/26             10  HTS-vft1eu-0003      vft1eu
# 3      2013/12/01             10  HTS-914324-0001      914324
# 4      2015/10/22             12  HTS-88ua9r-0001      88ua9r
# ...           ...            ...              ...         ...
# 26547  2016/11/19             13  HTS-n641x4-0001      n641x4
# 26548  2016/08/02              4  HTS-q0nm12-0001      q0nm12
# 26549  2017/03/09              6  HTS-sby0iz-0001      sby0iz
# 26550  2016/10/04             11  HTS-uz70x4-0001      uz70x4
# 26551  2016/12/16              9  HTS-xnbc22-0001      xnbc22
#
#        tshirt_category  tshirt_price  tshirt_quantity
# 0      White T-Shirt M          20.0                1
# 1      White T-Shirt M          20.0                1
# 2      White T-Shirt F          18.0                3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26552 entries, 0 to 26551
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_date       26552 non-null  object
#  1   pages_visited    26552 non-null  int64
#  2   order_id         26552 non-null  object
#  3   customer_id      26552 non-null  object
#  4   tshirt_category  26552 non-null  object
#  5   tshirt_price     26552 non-null  float64
#  6   tshirt_quantity  26552 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        pages_visited  tshirt_price  tshirt_quantity
# count   26552.000000  26552.000000     26552.000000
# mean       10.838016     20.223768         2.693394
# std         3.589299      2.220651         3.456182
# min         2.000000     17.500000         1.000000
# 25%         8.000000     18.000000         1.000000
# 50%        11.000000     20.000000         2.000000
# 75%        13.000000     23.000000         3.000000
# max        28.000000     24.000000        29.000000

# %%
df.head()
# Out:
#    order_date  pages_visited         order_id customer_id  tshirt_category  \
# 0  2016/09/04              9  HTS-038040-0002      038040  White T-Shirt M
# 1  2014/11/14             11  HTS-801797-0001      801797  White T-Shirt M
# 2  2017/02/26             10  HTS-vft1eu-0003      vft1eu  White T-Shirt F
# 3  2013/12/01             10  HTS-914324-0001      914324      Wh Tshirt F
# 4  2015/10/22             12  HTS-88ua9r-0001      88ua9r  White T-Shirt M
#
#    tshirt_price  tshirt_quantity
# 0          20.0                1
# 1          20.0                1
# 2          18.0                3
# 3          18.0                1
# 4          20.0                1

# %% [markdown]
# AD**.1** Zamień order_date na format daty. Upewnij się, że w rezultacie data będzie w formacie
# : rok-miesiąc-dzień;

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df
# Out:
#       order_date  pages_visited         order_id customer_id  tshirt_category  \
# 0     2016-09-04              9  HTS-038040-0002      038040  White T-Shirt M
# 1     2014-11-14             11  HTS-801797-0001      801797  White T-Shirt M
# 2     2017-02-26             10  HTS-vft1eu-0003      vft1eu  White T-Shirt F
# 3     2013-12-01             10  HTS-914324-0001      914324      Wh Tshirt F
# 4     2015-10-22             12  HTS-88ua9r-0001      88ua9r  White T-Shirt M
# ...          ...            ...              ...         ...              ...
# 26547 2016-11-19             13  HTS-n641x4-0001      n641x4  White T-Shirt M
# 26548 2016-08-02              4  HTS-q0nm12-0001      q0nm12  White T-Shirt M
# 26549 2017-03-09              6  HTS-sby0iz-0001      sby0iz  White T-Shirt M
# 26550 2016-10-04             11  HTS-uz70x4-0001      uz70x4           Hoodie
# 26551 2016-12-16              9  HTS-xnbc22-0001      xnbc22  Black T-Shirt M
#
# ...

# %%
df.order_date.dt.strftime("%Y.%m.%d")
# Out:
# 0        2016.09.04
# 1        2014.11.14
# 2        2017.02.26
# 3        2013.12.01
# 4        2015.10.22
#             ...
# 26547    2016.11.19
# 26548    2016.08.02
# 26549    2017.03.09
# 26550    2016.10.04
# 26551    2016.12.16
# Name: order_date, Length: 26552, dtype: object

# %% [markdown]
# AD.2 Sprawdź ile i jakie unikalne wartości znajdują się w kolumnie T-shirt category

# %%
df['tshirt_category'].unique()
# Out:
# array(['White T-Shirt M', 'White T-Shirt F', 'Wh Tshirt F',
#        'Black T-Shirt F', 'Hoodie', 'Black T-Shirt M', 'Tennis Shirt',
#        'Wh Tshirt M', 'Bl Tshirt F', 'Bl Tshirt M'], dtype=object)

# %%
df['tshirt_category'].nunique()
# Out:
# 10

# %% [markdown]
# Ad. 3
# Wyczyść kolumnę tshirt_category normalizując nazwy produktów. Upewnij się, że dla każdej kategorii funkcjonuje jedna nazwa, np. zamiast white i wh jest tylko jedna wersja white. Skorzystaj z klasy string i metody apply

# %%
x = df['tshirt_category'].replace({'Wh Tshirt M':'White T-Shirt M', 'Wh Tshirt F':'White T-Shirt F', 'Bl Tshirt M':'Black T-Shirt M','Bl Tshirt F':'Black T-Shirt F'})
x
# Out:
# 0        White T-Shirt M
# 1        White T-Shirt M
# 2        White T-Shirt F
# 3        White T-Shirt F
# 4        White T-Shirt M
#               ...
# 26547    White T-Shirt M
# 26548    White T-Shirt M
# 26549    White T-Shirt M
# 26550             Hoodie
# 26551    Black T-Shirt M
# Name: tshirt_category, Length: 26552, dtype: object

# %%
df['tshirt_category']=x
df
# Out:
#       order_date  pages_visited         order_id customer_id  tshirt_category  \
# 0     2016-09-04              9  HTS-038040-0002      038040  White T-Shirt M
# 1     2014-11-14             11  HTS-801797-0001      801797  White T-Shirt M
# 2     2017-02-26             10  HTS-vft1eu-0003      vft1eu  White T-Shirt F
# 3     2013-12-01             10  HTS-914324-0001      914324  White T-Shirt F
# 4     2015-10-22             12  HTS-88ua9r-0001      88ua9r  White T-Shirt M
# ...          ...            ...              ...         ...              ...
# 26547 2016-11-19             13  HTS-n641x4-0001      n641x4  White T-Shirt M
# 26548 2016-08-02              4  HTS-q0nm12-0001      q0nm12  White T-Shirt M
# 26549 2017-03-09              6  HTS-sby0iz-0001      sby0iz  White T-Shirt M
# 26550 2016-10-04             11  HTS-uz70x4-0001      uz70x4           Hoodie
# 26551 2016-12-16              9  HTS-xnbc22-0001      xnbc22  Black T-Shirt M
#
# ...

# %%
df['tshirt_category'].unique()
# Out:
# array(['White T-Shirt M', 'White T-Shirt F', 'Black T-Shirt F', 'Hoodie',
#        'Black T-Shirt M', 'Tennis Shirt'], dtype=object)

# %%
df.replace({"Hoodie" : "- Hoodie -", "Tennis Shirt": "- Tennis_Shirt -" }, inplace=True)
df
# Out:
#       order_date  pages_visited         order_id customer_id  tshirt_category  \
# 0     2016-09-04              9  HTS-038040-0002      038040  White T-Shirt M
# 1     2014-11-14             11  HTS-801797-0001      801797  White T-Shirt M
# 2     2017-02-26             10  HTS-vft1eu-0003      vft1eu  White T-Shirt F
# 3     2013-12-01             10  HTS-914324-0001      914324  White T-Shirt F
# 4     2015-10-22             12  HTS-88ua9r-0001      88ua9r  White T-Shirt M
# ...          ...            ...              ...         ...              ...
# 26547 2016-11-19             13  HTS-n641x4-0001      n641x4  White T-Shirt M
# 26548 2016-08-02              4  HTS-q0nm12-0001      q0nm12  White T-Shirt M
# 26549 2017-03-09              6  HTS-sby0iz-0001      sby0iz  White T-Shirt M
# 26550 2016-10-04             11  HTS-uz70x4-0001      uz70x4       - Hoodie -
# 26551 2016-12-16              9  HTS-xnbc22-0001      xnbc22  Black T-Shirt M
#
# ...

# %% [markdown]
# Ad. 4
# Rozdziel kolumnę tshirt category na 3 kolumny:
# tshirt_type, która będzie mówiła o tym czy jest to koszulka, bluza czy coś innego,
# tshirt_size, która będzie informowała o rozmiarze koszulki, i tshirt_colour, która będzie informowała o kolorze. Skorzystaj z metody apply.

# %%
df[['tshirt_colour', 'tshirt_type', 'tshirt_M/F']]= df['tshirt_category'].str.split(expand=True)
df
# Out:
#       order_date  pages_visited         order_id customer_id  tshirt_category  \
# 0     2016-09-04              9  HTS-038040-0002      038040  White T-Shirt M
# 1     2014-11-14             11  HTS-801797-0001      801797  White T-Shirt M
# 2     2017-02-26             10  HTS-vft1eu-0003      vft1eu  White T-Shirt F
# 3     2013-12-01             10  HTS-914324-0001      914324  White T-Shirt F
# 4     2015-10-22             12  HTS-88ua9r-0001      88ua9r  White T-Shirt M
# ...          ...            ...              ...         ...              ...
# 26547 2016-11-19             13  HTS-n641x4-0001      n641x4  White T-Shirt M
# 26548 2016-08-02              4  HTS-q0nm12-0001      q0nm12  White T-Shirt M
# 26549 2017-03-09              6  HTS-sby0iz-0001      sby0iz  White T-Shirt M
# 26550 2016-10-04             11  HTS-uz70x4-0001      uz70x4       - Hoodie -
# 26551 2016-12-16              9  HTS-xnbc22-0001      xnbc22  Black T-Shirt M
#
# ...

# %%
df['tshirt_colour'].unique()
# Out:
# array(['White', 'Black', '-'], dtype=object)

# %%
df['tshirt_M/F'].unique()
# Out:
# array(['M', 'F', '-'], dtype=object)

# %%
df['tshirt_type'].unique()
# Out:
# array(['T-Shirt', 'Hoodie', 'Tennis_Shirt'], dtype=object)

# %% [markdown]
# **Ad. 5**
# **Znajdź zamówienia złożone między 31 grudnia 2014 a 2 sierpnia 2016.**

# %%
df_filter = df[(df['order_date'] >= '2014-12-31') & (df['order_date'] <= '2016-08-2')]
df_filter
# Out:
#       order_date  pages_visited         order_id customer_id  tshirt_category  \
# 4     2015-10-22             12  HTS-88ua9r-0001      88ua9r  White T-Shirt M
# 5     2016-01-15              9  HTS-061311-0003      061311  Black T-Shirt F
# 12    2015-11-24             15  HTS-je57lh-0001      je57lh       - Hoodie -
# 13    2015-10-10              8  HTS-252675-0002      252675  White T-Shirt M
# 15    2015-11-29             15  HTS-heb26i-0001      heb26i  Black T-Shirt F
# ...          ...            ...              ...         ...              ...
# 26496 2016-06-02              2  HTS-5b4bg6-0001      5b4bg6  Black T-Shirt F
# 26513 2016-07-05             12  HTS-bt08zd-0001      bt08zd  White T-Shirt F
# 26515 2016-07-27             17  HTS-gsc3f6-0001      gsc3f6       - Hoodie -
# 26540 2016-06-08              7  HTS-6ba0i0-0001      6ba0i0  White T-Shirt M
# 26548 2016-08-02              4  HTS-q0nm12-0001      q0nm12  White T-Shirt M
#
# ...

# %%
df_filter['order_date'].min()
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
df_filter['order_date'].max()
# Out:
# Timestamp('2016-08-02 00:00:00')

# %% [markdown]
# Zadanie 2 (4 pkt)
#
#
# Wgraj plik customers.csv do ramki danych.
#
# Następnie:
# 1. Wypisz kolumny;
# 2. Porównaj rozmiar ramki z rozmiarem ramki w zadaniu 1;
# 3. Zmień nazwę kolumny customerID  na customer_id upewniając się, że dane zmiana zostanie zapisana w pamięci dzięki jednemu z argumentów metody do zmiany nazwy kolumny;
# 4. Połącz ramkę orders z ramką customers po kolumnie customer_id. Z której metody skorzystasz? Zostaw odpowiedź w komentarzu do zadania w kodzie (np. blok komentarzem ‘’’ ‘’’).

# %%
import pandas as pd
import numpy as np
data1=pd.read_csv('/content/drive/MyDrive/PJATK/PAD/ćwiczenia/PAD_04/customers.csv')
data1
df_customers = pd.DataFrame(data1)
df_customers
# Out:
#       customerID gender   birthdate  \
# 0         886900      M   1953/10/5
# 1         038040      F  1946/12/21
# 2         698696      F   1983/12/1
# 3         sn9keh      M   1990/9/23
# 4         496907      M    1869/6/8
# ...          ...    ...         ...
# 18761     m1yyx6      M   1999/8/19
# 18762     744375      F  1941/10/22
# 18763     t6pxeo      F   1950/5/10
# 18764     930049      F  1979/10/22
# 18765     950728      M   1997/9/18
#
#                                               user_agent       ip_address  \
# 0      Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     69.8.136.110
# 1      Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...    67.74.254.174
# 2      Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...    95.135.70.206
# 3      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...    129.50.205.26
# 4      Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...     81.98.234.29
# ...                                                  ...              ...
# ...

# %% [markdown]
# **Ad1. Wypisz kolumny**

# %%
df_customers.columns
# Out:
# Index(['customerID', 'gender', 'birthdate', 'user_agent', 'ip_address',
#        'campaign'],
#       dtype='object')

# %% [markdown]
# **Ad.2 Porównaj rozmiar ramki z rozmiarem ramki w zadaniu 1**

# %%
print(df_customers.size)
print(df_customers.shape)
# Out:
# 112596
# (18766, 6)

# %%
print(df.size)
print(df.shape)
# Out:
# 265520
# (26552, 10)

# %% [markdown]
# AD. 3 Zmień nazwę kolumny customerID na customer_id upewniając się, że dane zmiana zostanie zapisana w pamięci dzięki jednemu z argumentów metody do zmiany nazwy kolumny;

# %%
df_customers.rename(columns={"customerID" : "customer_id"}, inplace=True)
df_customers
# Out:
#       customer_id gender   birthdate  \
# 0          886900      M   1953/10/5
# 1          038040      F  1946/12/21
# 2          698696      F   1983/12/1
# 3          sn9keh      M   1990/9/23
# 4          496907      M    1869/6/8
# ...           ...    ...         ...
# 18761      m1yyx6      M   1999/8/19
# 18762      744375      F  1941/10/22
# 18763      t6pxeo      F   1950/5/10
# 18764      930049      F  1979/10/22
# 18765      950728      M   1997/9/18
#
#                                               user_agent       ip_address  \
# 0      Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     69.8.136.110
# 1      Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...    67.74.254.174
# 2      Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...    95.135.70.206
# 3      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...    129.50.205.26
# 4      Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...     81.98.234.29
# ...

# %% [markdown]
# **Ad.4 Połącz ramkę orders z ramką customers po kolumnie customer_id. Z której metody skorzystasz? Zostaw odpowiedź w komentarzu do zadania w kodzie (np. blok komentarzem ‘’’ ‘’’).**

# %%
nowa=df.merge(df_customers, how='inner', on='customer_id')
nowa
'''
Koszystam z metody 'merge', poniewaz dziala na dwoch data-frame'ach co pasuje do naszego formatu danych.
Co wiecej, jest ona wygodna poniewaz mozna jasno okreslic 'po ktorej kolumnie' mergujemy uzywajac jej nazwy.
Dodatkowo 'merge' daje nam opcje laczenia poprzez przeciecie rekordow po okreslonej kolumnie (opcja how='inner'),
ktora gwarantuje, ze w przypadku rekordu ktorego nie ma w pierwszej ramce danych, a jest w drugiej (lub odwrotnie)
nie otrzymamy rekordu wyjsciowego, ktory jest czesciowo wypelniony NaNami.
'''
# Out:
#       order_date  pages_visited         order_id customer_id  \
# 0     2016-09-04              9  HTS-038040-0002      038040
# 1     2014-06-04             13  HTS-038040-0001      038040
# 2     2014-11-14             11  HTS-801797-0001      801797
# 3     2015-10-22             12  HTS-801797-0002      801797
# 4     2017-02-26             10  HTS-vft1eu-0003      vft1eu
# ...          ...            ...              ...         ...
# 25877 2016-11-02             11  HTS-762534-0001      762534
# 25878 2016-11-16              4  HTS-hrpv38-0001      hrpv38
# 25879 2014-07-12             16  HTS-978569-0001      978569
# 25880 2016-08-05             11  HTS-k0batl-0001      k0batl
# 25881 2017-03-13             11  HTS-200121-0001      200121
#
#         tshirt_category  tshirt_price  tshirt_quantity tshirt_colour  \
# 0       White T-Shirt M          20.0                1         White
# 1       White T-Shirt F          18.0                1         White
# ...

# %% [markdown]
# Zadanie 3 (1 pkt)
#
# Nową ramkę (połączenie orders i customers) zapisz do pliku csv, ale zapisz bez kolumny z indeksem.

# %%
nowa.to_csv("/content/drive/MyDrive/PJATK/PAD/ćwiczenia/PAD_04/merged_frames_no_idx.csv", index=False)
